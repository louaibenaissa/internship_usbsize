# %% [markdown]
# # Internship Project
#
# ## Introduction
# This internship project focuses on the development of an image processing workflow for analyzing images captured by a disoriented camera inside a USB image box. The primary goal is to correct the disorientation, enhance the image quality, and prepare the data for further processing.
#
# In this notebook, we will cover the image processing aspects of the project, including:
# - Capturing and correcting the orientation of the image.
# - Enhancing the image for better clarity and usability.
#
# The classification and number detection parts will be discussed in the next notebook.
#
# This project was carried out by **BENAISSA Louai Abdallah** , **FERROUKHI Khaled** and **MEDDAH Ahmed Ascem** as part of their internship.
#
# ## Objective
# The objective of this notebook is to illustrate the techniques and methods used to process the captured images and prepare them for classification in subsequent stages.
#
# ---

# %%
from support import *

# %% [markdown]
# # I. Pre-processing

# %% [markdown]
# ## 1. Image Loading

# %%
Image = load_images("4.jpg")
plt.imshow(Image)

# %% [markdown]
# ## 2. Contour Detection

# %%
Image_corners = cntr_find(Image)
contoured_img = Image.copy()
cv.drawContours(contoured_img,[Image_corners],-1,(0,255,0),3)

plt.imshow(contoured_img)
plt.show()

# %% [markdown]
# ## 3. Boxing the images

# %%
Image_box = box_img(Image_corners, Image)
plt.imshow(Image_box)

# %% [markdown]
# ## 4. Image equalization

# %%
Image_equa = equalizer(Image_box)
plt.imshow(Image_equa)

# %% [markdown]
# ## 5. Image rotation

# %%
lower_red_orange = np.array([0, 120, 50])
upper_red_orange = np.array([5, 255, 255])

# %%
logo = mask_red_orange(Image_box)
plt.imshow(logo)

# %%
Image_final = rotate(Image_equa)
plt.imshow(Image_final)

# %% [markdown]
# ## 6. Get num

# %%
num = get_num(Image_final)
thres , black = cv.threshold(num, 128, 255, cv.THRESH_BINARY)


plt.imshow(black,'gray')
